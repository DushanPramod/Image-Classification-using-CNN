# %% [markdown]
# #### Importing the libraries

# %%
import tensorflow as tf
import pathlib
import PIL
import numpy as np
import cv2
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# #### Create a images dictionary according to there class

# %%
data_dir = pathlib.Path('D:/flower_photos')
classes = [ 'roses','daisy','dandelion','sunflowers','tulips']
images_dict = {class_name:list(data_dir.glob(class_name + '/*')) for class_name in classes}

# %% [markdown]
# #### create resized image array (x) and corresponding classes array (y)

# %%
X,y = [],[]

for class_name, images in images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img,(180,180))
        X.append(resized_img)
        y.append(classes.index(class_name))
X = np.array(X)
y = np.array(y)

# %%
X.shape,y.shape
# Out:
# ((3670, 180, 180, 3), (3670,))

# %% [markdown]
# #### Divide the dataset for test and train

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=0)

# %% [markdown]
# #### Data Visualization

# %%
def plot_sample(X, y, sample_indexes):
    for index in sample_indexes:
        plt.figure(figsize = (10,2))
        plt.imshow(X[index])
        plt.xlabel(classes[y[index]])

# %%
plot_sample(X_train, y_train, range(5))

# %% [markdown]
# #### Scale images

# %%
X_train_scaled = X_train / 255
X_test_scaled = X_test / 255

# %% [markdown]
# #### Build convolutional neural network and train it

# %%
num_classes = 5

model = Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(180, 180,3)),
  layers.experimental.preprocessing.RandomRotation(0.1),
  layers.experimental.preprocessing.RandomZoom(0.1),
    
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
    
  layers.Dense(128, activation='relu'),
  layers.Dense(64, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(X_train_scaled, y_train, epochs=30)
# Out:
# Epoch 1/30
# 86/86 [==============================] - 83s 939ms/step - loss: 1.5269 - accuracy: 0.3136
# Epoch 2/30
# 86/86 [==============================] - 81s 939ms/step - loss: 1.0986 - accuracy: 0.5494
# Epoch 3/30
# 86/86 [==============================] - 79s 924ms/step - loss: 1.0057 - accuracy: 0.5914
# Epoch 4/30
# 86/86 [==============================] - 85s 994ms/step - loss: 0.8905 - accuracy: 0.6549
# Epoch 5/30
# 86/86 [==============================] - 79s 913ms/step - loss: 0.8217 - accuracy: 0.6864
# Epoch 6/30
# 86/86 [==============================] - 80s 929ms/step - loss: 0.8272 - accuracy: 0.6673
# Epoch 7/30
# 86/86 [==============================] - 80s 929ms/step - loss: 0.7092 - accuracy: 0.7330
# Epoch 8/30
# 86/86 [==============================] - 81s 943ms/step - loss: 0.6878 - accuracy: 0.7426
# Epoch 9/30
# 86/86 [==============================] - 84s 981ms/step - loss: 0.6607 - accuracy: 0.7579
# Epoch 10/30
# 86/86 [==============================] - 81s 940ms/step - loss: 0.6170 - accuracy: 0.7636
# Epoch 11/30
# 86/86 [==============================] - 83s 960ms/step - loss: 0.6545 - accuracy: 0.7510
# Epoch 12/30
# 86/86 [==============================] - 75s 874ms/step - loss: 0.5705 - accuracy: 0.7806
# Epoch 13/30
# 86/86 [==============================] - 81s 942ms/step - loss: 0.5628 - accuracy: 0.7864
# Epoch 14/30
# 86/86 [==============================] - 77s 896ms/step - loss: 0.5372 - accuracy: 0.7975
# Epoch 15/30
# 86/86 [==============================] - 83s 965ms/step - loss: 0.4872 - accuracy: 0.8089
# Epoch 16/30
# 86/86 [==============================] - 85s 993ms/step - loss: 0.4707 - accuracy: 0.8235
# Epoch 17/30
# 86/86 [==============================] - 84s 972ms/step - loss: 0.4749 - accuracy: 0.8207
# Epoch 18/30
# 86/86 [==============================] - 82s 953ms/step - loss: 0.4294 - accuracy: 0.8306
# Epoch 19/30
# 86/86 [==============================] - 81s 942ms/step - loss: 0.4686 - accuracy: 0.8224
# Epoch 20/30
# 86/86 [==============================] - 81s 939ms/step - loss: 0.4240 - accuracy: 0.8433
# Epoch 21/30
# 86/86 [==============================] - 82s 951ms/step - loss: 0.4059 - accuracy: 0.8514
# Epoch 22/30
# 86/86 [==============================] - 82s 958ms/step - loss: 0.3573 - accuracy: 0.8629
# Epoch 23/30
# 86/86 [==============================] - 93s 1s/step - loss: 0.3832 - accuracy: 0.8586
# Epoch 24/30
# 86/86 [==============================] - 88s 1s/step - loss: 0.3511 - accuracy: 0.8728
# Epoch 25/30
# 86/86 [==============================] - 82s 948ms/step - loss: 0.3340 - accuracy: 0.8707
# Epoch 26/30
# 86/86 [==============================] - 84s 978ms/step - loss: 0.2907 - accuracy: 0.8982
# Epoch 27/30
# 86/86 [==============================] - 83s 967ms/step - loss: 0.2894 - accuracy: 0.8895
# Epoch 28/30
# 86/86 [==============================] - 81s 945ms/step - loss: 0.2869 - accuracy: 0.8800
# Epoch 29/30
# 86/86 [==============================] - 68s 784ms/step - loss: 0.2673 - accuracy: 0.9051
# Epoch 30/30
# 86/86 [==============================] - 73s 845ms/step - loss: 0.2599 - accuracy: 0.9065

# %% [markdown]
# #### Evaluate the model

# %%
model.evaluate(X_test_scaled, y_test)
# Out:
# 29/29 [==============================] - 7s 227ms/step - loss: 0.8496 - accuracy: 0.7462
# [0.8496279716491699, 0.7461873888969421]

# %% [markdown]
# #### Classification report

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_pred = model.predict(X_test_scaled)
y_pred_classes = [np.argmax(element) for element in y_pred]
print("Classification Report")
print(classification_report(y_test,y_pred_classes))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.68      0.69      0.69       176
#            1       0.82      0.71      0.76       154
#            2       0.82      0.73      0.77       226
#            3       0.73      0.85      0.79       150
#            4       0.70      0.76      0.73       212
#
#     accuracy                           0.75       918
#    macro avg       0.75      0.75      0.75       918
# weighted avg       0.75      0.75      0.75       918

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels = y_test, predictions = y_pred_classes)
plt.figure(figsize = (10,7))
sn.heatmap(data=cm, annot=True, fmt='d', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
